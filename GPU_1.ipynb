# %% [markdown]
# <a href="https://colab.research.google.com/github/phu1612508/GPU/blob/master/GPU_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt update -qq;
# !wget https://developer.nvidia.com/compute/cuda/8.0/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb;
# !dpkg -i cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb;
# !apt-key add /var/cuda-repo-8-0-local-ga2/7fa2af80.pub;
# !apt-get update -qq;
# !apt-get install cuda gcc-5 g++-5 -y -qq;
# !ln -s /usr/bin/gcc-5 /usr/local/cuda/bin/gcc;
# !ln -s /usr/bin/g++-5 /usr/local/cuda/bin/g++;
# !apt install cuda-8.0;
# Out:
# 24 packages can be upgraded. Run 'apt list --upgradable' to see them.
# --2020-01-10 05:13:55--  https://developer.nvidia.com/compute/cuda/8.0/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# Resolving developer.nvidia.com (developer.nvidia.com)... 192.229.182.215
# Connecting to developer.nvidia.com (developer.nvidia.com)|192.229.182.215|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://developer.download.nvidia.com/compute/cuda/8.0/secure/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64.deb?i2tSUCaT_aws4Hj6zWaj9Uy3cddCvAKSLW3SdODIZCP9d7DSyCcGqK_eAlGwnPNpu0if3Ww2Aguo9W75pepp-Vobwv2T6RHuJTufkFiJCL49iwEgdXty87NxDUKhX1D5pZcbZVeC2QBllk_20Fw8X3qtLdzfNA6btN82wy1E6PsYOHmNIpx39RZQgvntU6hLfKDATthwS1AoWCVL4JY4ra4ezA [following]
# ...

# %%
# !ln -s /usr/bin/gcc-5 /usr/local/cuda/bin/gcc
# !ln -s /usr/bin/g++-5 /usr/local/cuda/bin/g++

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2016 NVIDIA Corporation
# Built on Tue_Jan_10_13:22:03_CST_2017
# Cuda compilation tools, release 8.0, V8.0.61

# %%
# !git clone https://github.com/phu1612508/GPU.git
# Out:
# Cloning into 'GPU'...
# remote: Enumerating objects: 134, done.
# remote: Counting objects: 100% (134/134), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 134 (delta 98), reused 101 (delta 71), pack-reused 0
# Receiving objects: 100% (134/134), 1.25 MiB | 2.90 MiB/s, done.
# Resolving deltas: 100% (98/98), done.

# %%
# !nvcc Baseline_1.cu -o bl1
# !nvcc Baseline_2.cu -o bl2
# !nvcc Baseline_3_v3.cu -o bl3
# !nvcc Baseline_4_v1.cu -o bl4
# Out:
# nvcc warning : The 'compute_20', 'sm_20', and 'sm_21' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc warning : The 'compute_20', 'sm_20', and 'sm_21' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc warning : The 'compute_20', 'sm_20', and 'sm_21' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc warning : The 'compute_20', 'sm_20', and 'sm_21' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).

# %%
# !./bl1
# !./bl2
# !./bl3
# !./bl4
# Out:
# **********GPU info**********
# Name: Tesla P100-PCIE-16GB
# Compute capability: 6.0
# Num SMs: 56
# Max num threads per SM: 2048
# Max num warps per SM: 64
# GMEM: 17071734784 byte
# SMEM per SM: 65536 byte
# SMEM per block: 49152 byte
# ****************************
#
# Input size: 1000000
#
# Num bits per digit: 4
#
# Hist block size: 512, scan block size: 512
#
# Radix sort by host
# Time: 77.834 ms
#
# Radix sort by thrust
# Time: 5.264 ms
# CORRECT :)
# **********GPU info**********
# Name: Tesla P100-PCIE-16GB
# Compute capability: 6.0
# Num SMs: 56
# Max num threads per SM: 2048
# Max num warps per SM: 64
# GMEM: 17071734784 byte
# SMEM per SM: 65536 byte
# SMEM per block: 49152 byte
# ****************************
#
# Input size: 1000000
#
# Num bits per digit: 4
#
# Hist block size: 512, scan block size: 512
#
# Radix sort by host
# Time: 72.626 ms
#
# Radix sort by device
# Time: 54.340 ms
# CORRECT :)
# **********GPU info**********
# Name: Tesla P100-PCIE-16GB
# ...

# %%
for i in range(0, 10):
  # !./bl1
  # !./bl2
  # !./bl3
  # !./bl4
  print("-----------------------------------")
# Out:
# **********GPU info**********
# Name: Tesla P100-PCIE-16GB
# Compute capability: 6.0
# Num SMs: 56
# Max num threads per SM: 2048
# Max num warps per SM: 64
# GMEM: 17071734784 byte
# SMEM per SM: 65536 byte
# SMEM per block: 49152 byte
# ****************************
#
# Input size: 1000000
#
# Num bits per digit: 4
#
# Hist block size: 512, scan block size: 512
#
# Radix sort by host
# Time: 70.284 ms
#
# Radix sort by thrust
# Time: 5.248 ms
# CORRECT :)
# **********GPU info**********
# Name: Tesla P100-PCIE-16GB
# Compute capability: 6.0
# Num SMs: 56
# Max num threads per SM: 2048
# Max num warps per SM: 64
# GMEM: 17071734784 byte
# SMEM per SM: 65536 byte
# SMEM per block: 49152 byte
# ****************************
#
# Input size: 1000000
#
# Num bits per digit: 4
#
# Hist block size: 512, scan block size: 512
#
# Radix sort by host
# Time: 70.536 ms
#
# Radix sort by device
# Time: 54.115 ms
# CORRECT :)
# **********GPU info**********
# Name: Tesla P100-PCIE-16GB
# ...

# %%
# !nvcc Baseline_4_v2.cu -o bl42
# !./bl42
# Out:
# nvcc warning : The 'compute_20', 'sm_20', and 'sm_21' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# **********GPU info**********
# Name: Tesla P100-PCIE-16GB
# Compute capability: 6.0
# Num SMs: 56
# Max num threads per SM: 2048
# Max num warps per SM: 64
# GMEM: 17071734784 byte
# SMEM per SM: 65536 byte
# SMEM per block: 49152 byte
# ****************************
#
# Input size: 1000000
#
# Num bits per digit: 4
#
# Block size: 512
# Radix sort by Thrust
# Time: 5.190 ms
#
# Radix sort by device
# Time (local hist): 150.445 ms
# Time (exclusive scan): 1.641 ms
# Time (local sort): 13336.994 ms
# Time (start value): 40.002 ms
# Time (scatter): 66.798 ms
# Time: 13598.490 ms
# CORRECT :)

# %%
# !nvcc Baseline_4_v3_banva.cu -o bl43
# !./bl43
# Out:
# nvcc warning : The 'compute_20', 'sm_20', and 'sm_21' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# **********GPU info**********
# Name: Tesla P100-PCIE-16GB
# Compute capability: 6.0
# Num SMs: 56
# Max num threads per SM: 2048
# Max num warps per SM: 64
# GMEM: 17071734784 byte
# SMEM per SM: 65536 byte
# SMEM per block: 49152 byte
# ****************************
#
# Input size: 1000000
#
# Num bits per digit: 4
#
# Block size: 512
# Radix sort by Thrust
# Time: 5.130 ms
#
# Radix sort by device
# Time (local hist): 7.823 ms
# Time (exclusive scan): 0.690 ms
# Time (local sort): 16417.398 ms
# Time (start value): 40.153 ms
# Time (scatter): 68.906 ms
# Time: 16537.703 ms
# CORRECT :)

# %%
# !nvcc Baseline_4_v5.cu -o bl44
# !./bl44
# Out:
# nvcc warning : The 'compute_20', 'sm_20', and 'sm_21' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# Baseline_4_v5.cu(114): warning: variable "start" was set but never used
#
# Baseline_4_v5.cu(114): warning: variable "start" was set but never used
#
# **********GPU info**********
# Name: Tesla P100-PCIE-16GB
# Compute capability: 6.0
# Num SMs: 56
# Max num threads per SM: 2048
# Max num warps per SM: 64
# GMEM: 17071734784 byte
# SMEM per SM: 65536 byte
# SMEM per block: 49152 byte
# ****************************
#
# Input size: 1000000
#
# Num bits per digit: 4
# lock size: 512
# Radix sort by Thrust
# Time: 5.182 ms
#
# Radix sort by device
# Time (local hist): 0.351 ms
# Time (exclusive scan): 0.655 ms
# Time (local sort): 3.179 ms
# Time (start value): 39.462 ms
# Time (scatter): 67.549 ms
# Time: 126.437 ms
# CORRECT :)

# %%
# !nvcc Baseline_4_v9.cu -o bl45
# !./bl45
# Out:
# nvcc warning : The 'compute_20', 'sm_20', and 'sm_21' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# Baseline_4_v9.cu(271): warning: variable "time4" was set but never used
#
# Baseline_4_v9.cu(271): warning: variable "time4" was set but never used
#
# **********GPU info**********
# Name: Tesla P100-PCIE-16GB
# Compute capability: 6.0
# Num SMs: 56
# Max num threads per SM: 2048
# Max num warps per SM: 64
# GMEM: 17071734784 byte
# SMEM per SM: 65536 byte
# SMEM per block: 49152 byte
# ****************************
#
# Input size: 1000000
#
# Num bits per digit: 4
#
# block size: 512
# Radix sort by Thrust
# Time: 5.194 ms
# ...

# %%
# !nvcc GPU/Baseline_4_v9.cu -o b
# !./b
# Out:
# nvcc warning : The 'compute_20', 'sm_20', and 'sm_21' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# GPU/Baseline_4_v9.cu(271): warning: variable "time4" was set but never used
#
# GPU/Baseline_4_v9.cu(271): warning: variable "time4" was set but never used
#
# **********GPU info**********
# Name: Tesla K80
# Compute capability: 3.7
# Num SMs: 13
# Max num threads per SM: 2048
# Max num warps per SM: 64
# GMEM: 11996954624 byte
# SMEM per SM: 114688 byte
# SMEM per block: 49152 byte
# ****************************
#
# Input size: 16777217
#
# Num bits per digit: 4
#
# block size: 512
# Radix sort by Thrust
# Time: 71.611 ms
#
# Radix sort by device
# Time (local hist): 60.853 ms
# Time (exclusive scan): 2.642 ms
# Time (local sort) + Time (start value): 157.927 ms
# Time (scatter): 13.229 ms
# Time: 353.777 ms
# CORRECT :)
